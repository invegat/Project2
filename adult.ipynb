# %%
import numpy as np

# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 0446-5F4D
#
#  Directory of c:\Users\camar\Downloads\CAP5771\project2
#
# 11/18/2022  01:17 AM    <DIR>          .
# 11/18/2022  01:17 AM    <DIR>          ..
# 11/18/2022  01:07 AM    <DIR>          .ipynb_checkpoints
# 11/18/2022  01:17 AM            16,041 adult.ipynb
# 11/18/2022  01:15 AM           109,758 adult_test.csv
# 11/18/2022  01:15 AM           433,817 adult_train.csv
# 11/18/2022  12:06 AM             2,045 path.txt
# 11/18/2022  01:06 AM               171 Pipfile
# 11/18/2022  01:06 AM            54,552 Pipfile.lock
# 11/17/2022  10:41 PM           187,637 project2.pdf
# 11/18/2022  12:38 AM             6,466 set.txt
#                8 File(s)        810,487 bytes
#                3 Dir(s)  732,395,589,632 bytes free

# %%
df = pd.read_csv("./adult_train.csv")

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num      marital.status  \
# 0   24   Private  176189       HS-grad              9  Married-civ-spouse
# 1   30   Private  161690     Assoc-voc             11       Never-married
# 2   60   Private  145493  Some-college             10            Divorced
# 3   42   Private  144995     Preschool              1       Never-married
# 4   23   Private   50341       Masters             14       Never-married
#
#           occupation   relationship   race     sex  capital.gain  \
# 0  Machine-op-inspct        Husband  White    Male             0
# 1     Prof-specialty  Not-in-family  White  Female             0
# 2       Adm-clerical  Not-in-family  White  Female             0
# 3  Handlers-cleaners  Not-in-family  White    Male             0
# 4              Sales  Not-in-family  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0             0              40  United-States  <=50K
# ...

# %%
df.drop(["fnlwgt","education","relationship"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    age workclass  education.num      marital.status         occupation   race  \
# 0   24   Private              9  Married-civ-spouse  Machine-op-inspct  White
# 1   30   Private             11       Never-married     Prof-specialty  White
# 2   60   Private             10            Divorced       Adm-clerical  White
# 3   42   Private              1       Never-married  Handlers-cleaners  White
# 4   23   Private             14       Never-married              Sales  White
#
#       sex  capital.gain  capital.loss  hours.per.week native.country income
# 0    Male             0             0              40  United-States  <=50K
# 1  Female             0             0              40  United-States  <=50K
# 2  Female             0             0              40  United-States  <=50K
# 3    Male             0             0              25  United-States  <=50K
# 4  Female             0             0              20  United-States  <=50K

# %%
df.dropna(inplace=True)

# %%
df["native.country"] =  np.where(df["native.country"] != "United-States","other", "United-States")

# %%
df.tail()
# Out:
#       age         workclass  education.num         marital.status  \
# 3995   35  Self-emp-not-inc             15     Married-civ-spouse
# 3996   35           Private             13  Married-spouse-absent
# 3997   36           Private             13               Divorced
# 3998   21           Private              9          Never-married
# 3999   50           Private              9     Married-civ-spouse
#
#           occupation                race     sex  capital.gain  capital.loss  \
# 3995  Prof-specialty               White    Male             0             0
# 3996  Prof-specialty  Asian-Pac-Islander  Female             0             0
# 3997  Prof-specialty               Black  Female             0           213
# 3998    Adm-clerical               White  Female             0             0
# 3999    Adm-clerical               White    Male             0             0
#
#       hours.per.week native.country income
# 3995              50  United-States   >50K
# ...

# %%
df.loc[df.workclass.isin(["Federal-gov", "Local-gov", "State-go"]), "workclass"] = "Gov"

# %%
df.loc[df.workclass.isin(["Without-pay, Never-worked"]), "workclass"] = "Not-working"

# %%
df.loc[df.workclass.isin(["Self-emp-inc", "Self-emp-not-inc"]), "workclass"] = "Self-employed"

# %%
df.tail()
# Out:
#       age      workclass  education.num         marital.status  \
# 3995   35  Self-employed             15     Married-civ-spouse
# 3996   35        Private             13  Married-spouse-absent
# 3997   36        Private             13               Divorced
# 3998   21        Private              9          Never-married
# 3999   50        Private              9     Married-civ-spouse
#
#           occupation                race     sex  capital.gain  capital.loss  \
# 3995  Prof-specialty               White    Male             0             0
# 3996  Prof-specialty  Asian-Pac-Islander  Female             0             0
# 3997  Prof-specialty               Black  Female             0           213
# 3998    Adm-clerical               White  Female             0             0
# 3999    Adm-clerical               White    Male             0             0
#
#       hours.per.week native.country income
# 3995              50  United-States   >50K
# ...
