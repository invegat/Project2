# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("./adult_test.csv")

# %%
df.head()
# Out:
#    age         workclass  fnlwgt   education  education.num  \
# 0   43  Self-emp-not-inc  292175     Masters             14
# 1   53           Private  169846     HS-grad              9
# 2   44           Private  198282   Bachelors             13
# 3   31           Private  114937  Assoc-acdm             12
# 4   38       Federal-gov  125933     Masters             14
#
#        marital.status       occupation relationship   race     sex  \
# 0            Divorced  Exec-managerial    Unmarried  White  Female
# 1  Married-civ-spouse     Adm-clerical         Wife  White  Female
# 2  Married-civ-spouse  Exec-managerial      Husband  White    Male
# 3  Married-civ-spouse     Adm-clerical      Husband  White    Male
# 4  Married-civ-spouse   Prof-specialty      Husband  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0             0             0              45  United-States   >50K
# ...

# %%
df.drop(["fnlwgt","education","relationship"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    age         workclass  education.num      marital.status       occupation  \
# 0   43  Self-emp-not-inc             14            Divorced  Exec-managerial
# 1   53           Private              9  Married-civ-spouse     Adm-clerical
# 2   44           Private             13  Married-civ-spouse  Exec-managerial
# 3   31           Private             12  Married-civ-spouse     Adm-clerical
# 4   38       Federal-gov             14  Married-civ-spouse   Prof-specialty
#
#     race     sex  capital.gain  capital.loss  hours.per.week native.country  \
# 0  White  Female             0             0              45  United-States
# 1  White  Female             0             0              40  United-States
# 2  White    Male         15024             0              60  United-States
# 3  White    Male             0             0              40  United-States
# 4  White    Male             0             0              40           Iran
#
#   income
# 0   >50K
# 1   >50K
# 2   >50K
# ...

# %%
df.dropna(inplace=True)

# %%
df.workclass.isnull().sum()
# Out:
# 0

# %%
df["native.country"] =  np.where(df["native.country"] != "United-States","other", "United-States")

# %%
df.tail()
# Out:
#      age  workclass  education.num         marital.status         occupation  \
# 995   33  State-gov             10               Divorced      Other-service
# 996   53    Private             13               Divorced              Sales
# 997   52    Private              5  Married-spouse-absent  Machine-op-inspct
# 998   35    Private              8     Married-civ-spouse       Craft-repair
# 999   56    Private              7              Separated  Machine-op-inspct
#
#                    race     sex  capital.gain  capital.loss  hours.per.week  \
# 995               Black  Female             0             0              40
# 996               White  Female         13550             0              43
# 997  Asian-Pac-Islander  Female             0             0              30
# 998               White  Female             0             0              50
# 999               White  Female             0             0              40
#
#     native.country income
# ...

# %%
df.loc[df.workclass.isin(["Federal-gov", "Local-gov", "State-gov"]), "workclass"] = "Gov"

# %%
df.loc[df.workclass.isin(["Without-pay", "Neverworked"]), "workclass"] = "Not-working"

# %%
df.loc[df.workclass.isin(["Self-emp-inc", "Self-emp-not-inc"]), "workclass"] = "Self-employed"

# %%
df.tail()
# Out:
#      age workclass  education.num         marital.status         occupation  \
# 995   33       Gov             10               Divorced      Other-service
# 996   53   Private             13               Divorced              Sales
# 997   52   Private              5  Married-spouse-absent  Machine-op-inspct
# 998   35   Private              8     Married-civ-spouse       Craft-repair
# 999   56   Private              7              Separated  Machine-op-inspct
#
#                    race     sex  capital.gain  capital.loss  hours.per.week  \
# 995               Black  Female             0             0              40
# 996               White  Female         13550             0              43
# 997  Asian-Pac-Islander  Female             0             0              30
# 998               White  Female             0             0              50
# 999               White  Female             0             0              40
#
#     native.country income
# ...

# %%
df.loc[df["marital.status"].isin(["Married-AF-spouse", "Married-civ-spouse"]), "marital.status"] = "Married"

# %%
df = df.rename(columns={"marital.status": "marital-status", "native.country": "native country"})

# %%
df.head()
# Out:
#    age      workclass  education.num marital-status       occupation   race  \
# 0   43  Self-employed             14       Divorced  Exec-managerial  White
# 1   53        Private              9        Married     Adm-clerical  White
# 2   44        Private             13        Married  Exec-managerial  White
# 3   31        Private             12        Married     Adm-clerical  White
# 4   38            Gov             14        Married   Prof-specialty  White
#
#       sex  capital.gain  capital.loss  hours.per.week native country income
# 0  Female             0             0              45  United-States   >50K
# 1  Female             0             0              40  United-States   >50K
# 2    Male         15024             0              60  United-States   >50K
# 3    Male             0             0              40  United-States   >50K
# 4    Male             0             0              40          other   >50K

# %%
df.loc[df["marital-status"].isin(["Married-spouse-absent", "Separated", "Divorced", "Widowed"]), "marital-status"]\
= "Not-married"

# %%
df.loc[df.occupation.isin(["Tech-support", "Adm-clerical", "Privhouse-serv", "Protective-serv", "Armed-Forces",\
    "Other-service"]),"occupation"] = "Other"

# %%
df.loc[df.occupation.isin(["Craft-repair","Farming-fishing", "Handlers-cleaners", "Machine-op-inspct", \
                           "Transport-moving", "Priv-house-serv"]), "occupation"] = "ManualWork"

# %%
df = df[df.occupation != '?']

# %%
df.tail()
# Out:
#      age workclass  education.num marital-status  occupation  \
# 995   33       Gov             10    Not-married       Other
# 996   53   Private             13    Not-married       Sales
# 997   52   Private              5    Not-married  ManualWork
# 998   35   Private              8        Married  ManualWork
# 999   56   Private              7    Not-married  ManualWork
#
#                    race     sex  capital.gain  capital.loss  hours.per.week  \
# 995               Black  Female             0             0              40
# 996               White  Female         13550             0              43
# 997  Asian-Pac-Islander  Female             0             0              30
# 998               White  Female             0             0              50
# 999               White  Female             0             0              40
#
#     native country income
# 995  United-States  <=50K
# 996  United-States   >50K
# 997          other  <=50K
# 998  United-States  <=50K
# ...

# %%
# df = pd.get_dummies(df)

# %%
df.workclass.unique()
# Out:
# array(['Self-employed', 'Private', 'Gov'], dtype=object)

# %% [markdown]
# workclass: Gov (Federal-gov, Local-gov, State-gov), Not-working (Without-pay, Neverworked), Private, Self-employed (Self-emp-inc, Self-emp-not-inc)

# %%
df.workclass.loc[df.workclass == '?'].count()
# Out:
# 0

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    age  education.num  capital.gain  capital.loss  hours.per.week  \
# 0   43             14             0             0              45
# 1   53              9             0             0              40
# 2   44             13         15024             0              60
# 3   31             12             0             0              40
# 4   38             14             0             0              40
#
#    workclass_Gov  workclass_Private  workclass_Self-employed  \
# 0              0                  0                        1
# 1              0                  1                        0
# 2              0                  1                        0
# 3              0                  1                        0
# 4              1                  0                        0
#
#    marital-status_Married  marital-status_Never-married  ...  \
# 0                       0                             0  ...
# 1                       1                             0  ...
# ...

# %%
df.to_csv("./adult_test.unpatched.pp.csv", index=False)
